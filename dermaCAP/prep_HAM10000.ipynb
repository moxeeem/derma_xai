# %% [markdown]
# # HAM10000 preparation

# %% [markdown]
# ```bash
# pip install -U isic-cli
# DEST="/workspace/clip_xai/dermaCAP/HAM10000"
# mkdir -p "$DEST"
# isic image download --collections 212 --limit 0 "$DEST"
# ```

# %%
from pathlib import Path
import pandas as pd

# %%
BASE_DIR   = Path("/workspace/clip_xai/dermaCAP")
HAM_DIR    = BASE_DIR / "HAM10000"
META_CSV   = HAM_DIR / "metadata.csv"          
OUT_CSV    = BASE_DIR / "ham10000_prepared.csv"
IMG_EXT    = ".jpg"

# %%
EXCLUDE = {"isic_id", "lesion_id", "copyright_license", "attribution"}

LABELS = {
    "age_approx": "Age (approx)",
    "anatom_site_general": "Anatomic site (general)",
    "anatom_site_special": "Anatomic site (special)",
    "concomitant_biopsy": "Concomitant biopsy",
    "diagnosis_1": "Diagnosis 1",
    "diagnosis_2": "Diagnosis 2",
    "diagnosis_3": "Diagnosis 3",
    "diagnosis_confirm_type": "Diagnosis confirm type",
    "image_manipulation": "Image manipulation",
    "image_type": "Image type",
    "melanocytic": "Melanocytic",
    "pixels_x": "Pixels X",
    "pixels_y": "Pixels Y",
    "sex": "Sex",
}

YESNO = {"true": "Yes", "false": "No", "yes": "Yes", "no": "No", "1": "Yes", "0": "No"}

# %%
df = pd.read_csv(META_CSV)

df
# Out:
#             isic_id      attribution copyright_license  age_approx  \
# 0      ISIC_0024306  MILK study team          CC-BY-NC        45.0
# 1      ISIC_0024307  MILK study team          CC-BY-NC        50.0
# 2      ISIC_0024308  MILK study team          CC-BY-NC        55.0
# 3      ISIC_0024309  MILK study team          CC-BY-NC        40.0
# 4      ISIC_0024310  MILK study team          CC-BY-NC        60.0
# ...             ...              ...               ...         ...
# 11715  ISIC_0036060  MILK study team          CC-BY-NC         NaN
# 11716  ISIC_0036061  MILK study team          CC-BY-NC         NaN
# 11717  ISIC_0036062  MILK study team          CC-BY-NC        70.0
# 11718  ISIC_0036063  MILK study team          CC-BY-NC         NaN
# 11719  ISIC_0036064  MILK study team          CC-BY-NC         NaN
#
#       anatom_site_general anatom_site_special  concomitant_biopsy  \
# 0                     NaN                 NaN               False
# 1         lower extremity                 NaN               False
# 2                     NaN                 NaN               False
# 3                     NaN                 NaN               False
# 4          anterior torso                 NaN                True
# ...                   ...                 ...                 ...
# 11715                 NaN                 NaN               False
# 11716                 NaN                 NaN               False
# 11717           head/neck                 NaN                True
# 11718                 NaN                 NaN               False
# 11719                 NaN                 NaN                True
#
#          diagnosis_1                                        diagnosis_2  \
# 0             Benign                  Benign melanocytic proliferations
# 1             Benign                  Benign melanocytic proliferations
# 2             Benign                  Benign melanocytic proliferations
# 3             Benign                  Benign melanocytic proliferations
# 4          Malignant    Malignant melanocytic proliferations (Melanoma)
# ...              ...                                                ...
# 11715         Benign                    Benign epidermal proliferations
# 11716         Benign                  Benign melanocytic proliferations
# 11717  Indeterminate             Indeterminate epidermal proliferations
# 11718         Benign                    Benign epidermal proliferations
# 11719      Malignant  Malignant adnexal epithelial proliferations - ...
#
#                       diagnosis_3            diagnosis_confirm_type  \
# 0                           Nevus  serial imaging showing no change
# 1                           Nevus  serial imaging showing no change
# 2                           Nevus  serial imaging showing no change
# 3                           Nevus  serial imaging showing no change
# 4                   Melanoma, NOS                    histopathology
# ...                           ...                               ...
# 11715  Pigmented benign keratosis     single image expert consensus
# 11716                       Nevus     single image expert consensus
# 11717  Solar or actinic keratosis                    histopathology
# 11718  Pigmented benign keratosis     single image expert consensus
# 11719        Basal cell carcinoma                    histopathology
#
#       image_manipulation   image_type   lesion_id  melanocytic  pixels_x  \
# 0                    NaN  dermoscopic  IL_7252831         True       600
# 1                    NaN  dermoscopic  IL_6125741         True       600
# 2                    NaN  dermoscopic  IL_3692653         True       600
# 3                    NaN  dermoscopic  IL_0959663         True       600
# 4                    NaN  dermoscopic  IL_8194852         True       600
# ...                  ...          ...         ...          ...       ...
# 11715                NaN  dermoscopic  IL_5218936        False       600
# 11716                NaN  dermoscopic  IL_5893216         True       600
# 11717                NaN  dermoscopic  IL_9294619        False       600
# 11718                NaN  dermoscopic  IL_6088695        False       600
# 11719                NaN  dermoscopic  IL_4973744        False       600
#
#        pixels_y     sex
# 0           450    male
# 1           450    male
# 2           450  female
# 3           450    male
# 4           450    male
# ...         ...     ...
# 11715       450     NaN
# 11716       450     NaN
# 11717       450  female
# 11718       450     NaN
# 11719       450     NaN
#
# [11720 rows x 18 columns]

# %%
def lbl(col: str) -> str:
    return LABELS.get(col, col.replace("_", " ").title())

def norm_bool(x):
    s = str(x).strip().lower()
    return YESNO.get(s, None)

def fmt(col, v):
    if pd.isna(v):
        return "Unknown"
    as_bool = norm_bool(v)
    if as_bool is not None:
        return as_bool
    try:
        f = float(v)
        return str(int(f)) if f.is_integer() else str(f)
    except:
        pass
    if col == "sex":
        s = str(v).strip().lower()
        if s in {"male","m"}: return "Male"
        if s in {"female","f"}: return "Female"
    return str(v)

df["img_path"] = HAM_DIR.as_posix() + "/" + df["isic_id"].astype(str) + IMG_EXT

cols_for_caption = [c for c in df.columns if c not in EXCLUDE and c != "img_path"]

df["caption"] = df.apply(
    lambda r: ", ".join(f"{lbl(c)}: {fmt(c, r[c])}" for c in cols_for_caption),
    axis=1
)

final = df[["img_path", "caption"]].copy()

final
# Out:
#                                                 img_path  \
# 0      /workspace/clip_xai/dermaCAP/HAM10000/ISIC_002...
# 1      /workspace/clip_xai/dermaCAP/HAM10000/ISIC_002...
# 2      /workspace/clip_xai/dermaCAP/HAM10000/ISIC_002...
# 3      /workspace/clip_xai/dermaCAP/HAM10000/ISIC_002...
# 4      /workspace/clip_xai/dermaCAP/HAM10000/ISIC_002...
# ...                                                  ...
# 11715  /workspace/clip_xai/dermaCAP/HAM10000/ISIC_003...
# 11716  /workspace/clip_xai/dermaCAP/HAM10000/ISIC_003...
# 11717  /workspace/clip_xai/dermaCAP/HAM10000/ISIC_003...
# 11718  /workspace/clip_xai/dermaCAP/HAM10000/ISIC_003...
# 11719  /workspace/clip_xai/dermaCAP/HAM10000/ISIC_003...
#
#                                                  caption
# 0      Age (approx): 45, Anatomic site (general): Unk...
# 1      Age (approx): 50, Anatomic site (general): low...
# 2      Age (approx): 55, Anatomic site (general): Unk...
# 3      Age (approx): 40, Anatomic site (general): Unk...
# 4      Age (approx): 60, Anatomic site (general): ant...
# ...                                                  ...
# 11715  Age (approx): Unknown, Anatomic site (general)...
# 11716  Age (approx): Unknown, Anatomic site (general)...
# 11717  Age (approx): 70, Anatomic site (general): hea...
# 11718  Age (approx): Unknown, Anatomic site (general)...
# 11719  Age (approx): Unknown, Anatomic site (general)...
#
# [11720 rows x 2 columns]

# %%
final.to_csv(OUT_CSV, index=False, encoding="utf-8")
print(f"OK → {OUT_CSV} | rows: {len(final)}")
# Out:
# OK → /workspace/clip_xai/dermaCAP/ham10000_prepared.csv | rows: 11720
